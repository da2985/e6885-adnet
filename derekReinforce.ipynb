# %% [markdown]
# <a href="https://colab.research.google.com/github/da2985/e6885-adnet/blob/main/derekReinforce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Please use the following two lines to load from Google Drive
#
# If your file is not there, upload it to https://drive.google.com/drive/folders/1tsPKyB2E1nW8Qw--kZ9GaeGW2u2-XoV6?usp=sharing

# %%
# This must be run within a Google Colab environment 
from google.colab import drive  
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
import os

sys.path.append('/content/gdrive/EE6885')

os.chdir("/content/gdrive/My Drive/EE6885")

# %% [markdown]
# ### LOOK FOR AVAILABLE DATASETS IN THE FOLLOWING CELL. DO NOT DELETE

# %%
# !ls adnet_datasets/OTB
# Out:
#  Basketball   Car1	 Deer	      Human3	 Mhyang         Soccer
#  Biker	      Car2	 Dog	      Human4	 MotorRolling   Subway
#  Bird1	      Car24	 Dog1	      Human5	 MountainBike   Surfer
#  Bird2	      Car4	 Doll	      Human6	 Panda	        Suv
#  BlurBody     CarDark	 DragonBaby   Human7	 RedTeam        Sylvester
#  BlurCar1     CarScale	 Dudek	      Human8	 Rubik	        Tiger1
#  BlurCar2     ClifBar	 FaceOcc1     Human9	 Shaking        Tiger2
#  BlurCar3     Coke	 FaceOcc2     Ironman	 Singer1        Toy
#  BlurCar4     Couple	 Fish	      Jogging	 Singer2        Trans
#  BlurFace     Coupon	 FleetFace    Jump	 Skater         Trellis
#  BlurOwl      Crossing	 Football1    Jumping	 Skater2        Twinnings
#  Board	      Crowds	 Freeman1     KiteSurf	'Skater2 (1)'   Vase
#  Bolt	      Dancer	 Girl	      Lemming	 Skating1       Walking
#  Bolt2	      Dancer2	 Girl2	      Liquor	 Skating2       Walking2
#  Box	      David2	 Gym	      Man	 Skating3       Woman
#  Boy	      David3	 Human2       Matrix	 Skiing

# %%
pip install hdf5storage
# Out:
# Collecting hdf5storage
#   Downloading hdf5storage-0.1.18-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (1.19.5)
# Requirement already satisfied: h5py>=2.1 in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.1->hdf5storage) (1.5.2)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.18

# %%
pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.7 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %%
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa

import tensorflow_probability as tfp
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import regularizers

import cv2
import glob
import hdf5storage
import math
import random
import re

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import scipy.io as sio

import linecache

from typing import Dict, List, Tuple
from operator import add
import copy

# %%
 # %load_ext autoreload 
 # %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MODEL DEFINITIONS

# %%
class ADNET(tf.keras.Model):

    ACTION_DIM = 11
    K = 10

    def __init__(self):
        super(ADNET, self).__init__()

        self.action_history = tf.keras.layers.Input(shape = (1,1, ADNET.ACTION_DIM * ADNET.K))

        self.conv1 = tf.keras.layers.Conv2D(filters = 96, kernel_size = (7, 7), strides = (2, 2), padding = 'VALID', activation = 'relu', name = 'conv_1')
        self.max1  = tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides = (1, 1), padding = 'VALID')
        self.conv2 = tf.keras.layers.Conv2D(filters = 256, kernel_size = (5, 5), strides = (2, 2), padding = 'VALID', activation = 'relu', name = 'conv_2')
        self.max2  = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides = (2, 2), padding = 'VALID')
        self.conv3 = tf.keras.layers.Conv2D(filters = 512, kernel_size = (3, 3), strides = (2, 2), padding = 'VALID', activation = 'relu', name = 'conv_3')
        self.max3  = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides = (1, 1), padding = 'VALID')
        
        self.fc1 = tf.keras.layers.Conv2D(filters = 512, kernel_size = (3, 3), padding = 'VALID', activation = 'relu', name = 'fc1')
        self.fc2 = tf.keras.layers.Conv2D(filters = 512, kernel_size = (1,1), padding = 'VALID', activation = 'relu', name = 'fc2')
        self.fc3 = tf.keras.layers.Conv2D(filters = 11, kernel_size = (1,1), padding = 'VALID', name = 'fc3',activation="softmax")
        self.fc4 = tf.keras.layers.Conv2D(filters = 2, kernel_size = (1,1), padding = 'VALID', name = 'fc4',activation="softmax")

        # TODO: ADD A SEED
        self.dropout1=tf.keras.layers.Dropout(0.2)
        self.dropout2=tf.keras.layers.Dropout(0.2)
        

    def build(self, action_history):
      super(ADNET, self).build((None, 112, 112, 3))
      self.action_history=action_history

    def setActionHistory(self, action_history):
      self.action_history=action_history.reshape((1, 1, 1, ADNET.ACTION_DIM * ADNET.K))

    def call(self, input_tensor, training=False):
        x = self.conv1(input_tensor)
        x = self.max1(x)
        x = self.conv2(x)
        x = self.max2(x)
        x = self.conv3(x)
        x = self.max3(x)

        x = self.fc1(x)
        x=  self.dropout1(x)
        x = self.fc2(x)
        x=  self.dropout2(x)
        x = tf.keras.layers.Concatenate(axis=-1)([x, self.action_history])
        action = self.fc3(x)
        confidence = self.fc4(x)
        return [action, confidence]

    def callForAction(self, input_tensor, training=False):
      '''
      Wrapper action for model.call() to only output action probabilities.
      For RL purposes, this is the only relevant output (as of 12/2/2021).
      '''
      return self.call(input_tensor, training)[0]

    def compile(self, optimizer):
   		super().compile(optimizer, loss={
         'output_1':tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
         'output_2': tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
         })
     
    def getEmbedding(self,input_tensor):
        x = self.conv1(input_tensor)
        x = self.max1(x)
        x = self.conv2(x)
        x = self.max2(x)
        x = self.conv3(x)
        x = self.max3(x)
        return tf.reshape(x,(-1,))

    def getFC1(self,input_tensor):
        x = self.conv1(input_tensor)
        x = self.max1(x)
        x = self.conv2(x)
        x = self.max2(x)
        x = self.conv3(x)
        x = self.max3(x)
        x = self.fc1(x)
        return x
      
    def debugModelSummary(self):
      '''
      call model.debugModelSummary().summary() to get around the inconvenience 
      from model.summary() returning 'multiple' for each layer's output shape
      '''
      dummyInput = tf.keras.layers.Input(shape = (112,112,3))
      return tf.keras.Model(inputs=[dummyInput], outputs = self.call(dummyInput))

def setWeights(model, weights, weights2):
  model.layers[0].set_weights([weights2["conv1f"],tf.reshape(weights2["conv1b"],(96,))])
  model.layers[2].set_weights([weights2["conv2f"],tf.reshape(weights2["conv2b"],(256,))])
  model.layers[4].set_weights([weights2["conv3f"],tf.reshape(weights2["conv3b"],(512,))])
  
  model.layers[6].set_weights([weights["fc4f"],tf.reshape(weights["fc4b"],(512,))])
  model.layers[7].set_weights([weights["fc5f"],tf.reshape(weights["fc5b"],(512,))])
  model.layers[8].set_weights([weights["fc6_1f"],tf.zeros(11)])
  model.layers[9].set_weights([weights["fc6_2f"],tf.zeros(2)])
  
  return model

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
class ADNET_v2(tf.keras.Model):
    def __init__(self):
        super(ADNET_v2, self).__init__()

        #self.action_history = tf.keras.layers.Input(shape = (1,1,110))
        self.action_history = tf.keras.layers.Input(shape = (110))

        self.resnet=tf.keras.applications.ResNet50V2(include_top=False,weights="imagenet",input_shape=(112,112,3),pooling="max")
        #self.resnet = tf.keras.applications.ResNet50V2(include_top=False,weights="imagenet",input_shape=(112,112,3),pooling=None)
        #self.conv1 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (4,4), padding = 'VALID', name = 'fc4',activation="relu")
        
        self.fc1 = tf.keras.layers.Dense(512,kernel_initializer='glorot_uniform',activation = 'relu', name = 'fc1')
        self.fc2 = tf.keras.layers.Dense(512,kernel_initializer='glorot_uniform', activation = 'relu', name = 'fc2')
        self.fc3 = tf.keras.layers.Dense(11,kernel_initializer='glorot_uniform', name = 'fc3',activation="softmax")
        self.fc4 = tf.keras.layers.Dense(2,kernel_initializer='glorot_uniform',name = 'fc4',activation="softmax")

        self.dropout1=tf.keras.layers.Dropout(0)
        self.dropout2=tf.keras.layers.Dropout(0)
        

    def build(self, action_history):
      super(ADNET_v2, self).build((None, 112, 112, 3))
      self.action_history=action_history
      self.resnet.trainable = False

    def setActionHistory(self, action_history):
      self.action_history=action_history

    def call(self, input_tensor, training=False):
        x = self.resnet(input_tensor)
        #x = self.conv1(x)

        x = self.fc1(x)
        x=  self.dropout1(x)
        x = self.fc2(x)
        x=  self.dropout2(x)
        x = tf.keras.layers.Concatenate(axis=-1)([x, self.action_history])
        action = self.fc3(x)
        confidence = self.fc4(x)
        return [action, confidence]

    def callForAction(self, input_tensor, training=False):
      '''
      Wrapper action for model.call() to only output action probabilities.
      For RL purposes, this is the only relevant output (as of 12/2/2021).
      '''
      return self.call(input_tensor, training)[0]

    # def compile(self, optimizer):
   	# 	super().compile(optimizer, loss={
    #      'output_1':tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    #      'output_2': tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
    #      })
     
    def debugModelSummary(self):
      '''
      call model.debugModelSummary().summary() to get around the inconvenience 
      from model.summary() returning 'multiple' for each layer's output shape
      '''
      dummyInput = tf.keras.layers.Input(shape = (112,112,3))
      return tf.keras.Model(inputs=[dummyInput], outputs = self.call(dummyInput))

# %% [markdown]
# # HELPER FUNCTIONS

# %%
# DEBUGGING helper functions for accessing getting ground truth and image files

def human_readable_action(index: int) -> str:
  '''
  Map action numbers to human readable strings
  '''
  def _get_action(index:int) -> str:
    if index == 0:
      return "left"
    elif index == 1:
      return "2x left"
    elif index == 2:
      return "right"
    elif index == 3:
      return "2x right"
    elif index == 4:
      return "up"
    elif index == 5:
      return "2x up"
    elif index == 6:
      return "down"
    elif index == 7:
      return "2x down"
    elif index == 8:
      return "stop"
    elif index == 9:
      return "scale down"
    elif index == 10 :
      return "scale up"
  return _get_action(index).upper()


def get_ground_truths(ground_truth_file: str) -> np.array:
  '''
  Use me to convert a ground_truth_file to a numpy array
  '''
  with open(ground_truth_file) as f:
    ground_truths = f.readlines()
    to_nparray = lambda s: np.array(re.findall('\d+', s), dtype=int)
    truths = list(map(to_nparray, ground_truths))
    return np.asarray(truths)
  return None

def plotNpImageBBox(img: np.array, bbox: np.array) -> np.array:
  '''
  Plots the bounding box on an image and returns the bounding box
  '''
  fig, ax = plt.subplots()
  x, y, w, h = bbox
  rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none')
  ax.add_patch(rect)
  plt.imshow(img)
  return bbox

def plotNpImageBBoxes(img: np.array, src_bbox: np.array, target_bbox: np.array, 
                      pred_bbox: np.array) -> np.array:
  '''
  Plots the bounding boxes on an image and returns the bounding box
  '''
  fig, ax = plt.subplots()
  x1, y1, w1, h1 = src_bbox
  x2, y2, w2, h2 = target_bbox
  x3, y3, w3, h3 = pred_bbox
  rect1 = patches.Rectangle((x1, y1), w1, h1, linewidth=1, edgecolor='b', facecolor='none')
  rect2 = patches.Rectangle((x2, y2), w2, h2, linewidth=1, edgecolor='g', facecolor='none')
  rect3 = patches.Rectangle((x3, y3), w3, h3, linewidth=1, edgecolor='r', facecolor='none')
  ax.add_patch(rect1)
  ax.add_patch(rect2)
  ax.add_patch(rect3)
  plt.imshow(img)
  return pred_bbox  

def plotImageBBox(img: str, bbox: np.array) -> np.array:
  '''
  Plots the bounding box on an image (from given filepath) and returns the 
  bounding box
  '''
  img = cv2.imread(img)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plotNpImageBBox(img, bbox)
  return bbox

def plotDatasetImageBBox(dataset: str, frame_no: int) -> Tuple[np.array, int]:
  '''
  Plot an image's bounding box. Returns the ground truth and frame number.
  WORKS FOR OTB100
  '''
  imgs = sorted(glob.glob("{0}/img/*".format(dataset)))
  gt = get_ground_truths("{0}/groundtruth_rect.txt".format(dataset))
  plotImageBBox(imgs[frame_no], gt[frame_no])
  return gt[frame_no], frame_no


print(plotDatasetImageBBox("adnet_datasets/OTB/Basketball", 50)[0])
print(plotDatasetImageBBox("adnet_datasets/OTB/BlurBody", 10)[0])
# Out:
# [290 239  34  81]
# [171 128  99 316]

# %%
# MOVEMENT helper functions

ALPHA = 0.03 # See p. 4 of the paper
STOP_ACTION_INDEX = 8
MIN_WINDOW_SIZE = 10

def calculate_IOU(bbox1: np.array, bbox2: np.array):
    x1, y1, w1, h1 = bbox1
    x2, y2, w2, h2 = bbox2
           
    i_x1 = max(x1, x2)
    i_y1 = max(y1, y2)
    i_x2 = min(x1 + w1, x2 + w2)
    i_y2 = min(y1 + h1, y2 + h2)
    if i_x1 >= i_x2 or i_y1 >= i_y2:
      return 0.0

    intersection_area = (i_x2 - i_x1) * (i_y2 - i_y1)
    box1_area = w1 * h1
    box2_area = w2 * h2
    
    iou = intersection_area / float(box1_area + box2_area - intersection_area)
    return iou


def move(image: np.array, bbox: np.array, action: str, 
         stride_magnitude: int=1) -> np.array:
  '''
  Returns the new bounding box after taking an action: 
  {"left", "right", "up", "down"}. Use stride to indicate the step size.
  '''
  if action not in set(["left", "right", "up", "down"]):
    raise RuntimeError("Invalid action taken :(") 
  
  x, y, w, h = bbox
  if action in set(["left", "right"]):
    step = max(1, int(ALPHA * w)) * stride_magnitude * (-1 if action=="left" else 1)
    x = max(0, min(int(x + step), image.shape[1] - w - 1)) 
  else:
    step = max(1, int(ALPHA * h)) * stride_magnitude * (-1 if action=="up" else 1)
    y = max(0, min(int(y + step), image.shape[0] - h - 1)) 

  return np.array([x, y, w, h])

def scale(image: np.array, bbox: np.array, scaleUp: bool):
  x, y, w, h = bbox
  deltaW, deltaH = max(2, ALPHA * w), max(2, ALPHA * h)
  if not scaleUp: 
    deltaW *= -1
    deltaH *= -1
  w = min(image.shape[1], max(MIN_WINDOW_SIZE, int(w + deltaW))) 
  h = min(image.shape[0], max(MIN_WINDOW_SIZE, int(h + deltaH)))
  x = int(x + -1 * deltaW / 2)
  y = int(y + -1 * deltaH / 2)
  return np.array([x, y, w, h])

def selectAction(img: np.array, bbox: np.array, index: int): 
  if index == 0 :
    bbox = move(img, bbox, "left")
  elif index == 1 :
    bbox = move(img, bbox, "left", stride_magnitude=2)
  elif index == 2 :
    bbox = move(img, bbox, "right")
  elif index == 3 :
    bbox = move(img, bbox, "right", stride_magnitude=2)  
  elif index == 4 :
    bbox = move(img, bbox, "up")  
  elif index == 5 :
    bbox = move(img, bbox, "up", stride_magnitude=2)
  elif index == 6 :
    bbox = move(img, bbox, "down")
  elif index == 7 :
    bbox = move(img, bbox, "down", stride_magnitude=2)
  elif index == 8:
    bbox = bbox
  elif index == 9 :
    bbox = scale(img, bbox, False)     # Scale Down
  elif index == 10 :
    bbox = scale(img, bbox, True)      # Scale Up

  x, y, w, h = bbox
  assert 0 <= x < img.shape[1] - w, "x:{0}, w:{1} is out of bounds: [0, {2})".format(x, w, img.shape[1])
  assert 0 <= y < img.shape[0] - h, "y:{0}, h:{1} is out of bounds: [0, {2})".format(y, h, img.shape[0])
  assert MIN_WINDOW_SIZE <= w <= img.shape[1], "w:{0}, is invalid".format(w)
  assert MIN_WINDOW_SIZE <= h <= img.shape[0], "h:{0} is invalid".format(h)
  return index, bbox


def selectMaxAction(img: np.array, bbox: np.array, action_probs: np.array): 
  a = tf.math.argmax(action_probs)
  return selectAction(img, bbox, a)


def sampleAction(img: np.array, bbox: np.array, action_probs: np.array):  
  # Normalize probabilities and make sure there's mass added to all of them
  action_probs = np.array(action_probs) + 1e-5
  action_probs /= action_probs.sum()
  
  a = np.random.choice(np.arange(len(action_probs)), p=action_probs)
  return selectAction(img, bbox, a)


def isStop(action: int):
  return action == STOP_ACTION_INDEX

# %%
# Update this with the appropriate dataset
TEST_IMAGE_PATH = "adnet_datasets/OTB/Couple/img/0082.jpg"
TEST_BBOX = get_ground_truths("adnet_datasets/OTB/Couple/groundtruth_rect.txt")[82]
TEST_IMAGE = cv2.imread(TEST_IMAGE_PATH)


# Update the following two vars
src_bbox = np.array([143, 131, 34, 87]) 
pred_bbox = np.array([138, 41, 32, 89])
print(plotNpImageBBoxes(TEST_IMAGE, src_bbox, TEST_BBOX, pred_bbox))


print("IOU: {0}".format(calculate_IOU(pred_bbox, src_bbox)))

print("Test bbox is: {0}".format(TEST_BBOX))
# Out:
# [138  41  32  89]
# IOU: 0.0
# Test bbox is: [159  50  21  82]

# %% [markdown]
# # RL PORTION

# %%
# Derek experimental

DISCOUNT_FACTOR = 1
MAX_ACTION_SEQ_LIMIT = 20
PROB_OFFSET = 1e-4 # use me in case probabilities converge to 1.0, but you want to keep exploring
VERBOSE = False

def getNonStopScore(bbox1: np.array, bbox2: np.array, gt: np.array) -> float:
  # Issues with this blowing up the gradient in the wrong direction
  prevIou = calculate_IOU(bbox1, gt) 
  nextIou = calculate_IOU(bbox2, gt)
  x1, y1 = bbox1[:2]
  x2, y2 = bbox2[:2]
  xg, yg = gt[:2]

  def dist(x1, y1, x2, y2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)
  
  # if prevIou == nextIou: EXPERIMENTED WITH USING EUCLIDEAN DISTANCE
  #   return -1 * (dist(x2, y2, xg, yg) - dist(x1, y1, xg, yg))
  result = nextIou - prevIou 
  return result 


def getFrame(dataset: str, frame: int) -> np.array:
  f_path = "{0}/img/{1}.jpg".format(dataset, str(frame).zfill(4))
  print("Frame path: {0}".format(f_path))
  img = cv2.imread(f_path)
  return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


def getPatch(img: np.array, bbox: np.array) -> tf.Tensor:

  def bbox2numpy(img: np.array, bbox: np.array) -> np.array:
    x, y, w, h, = bbox
    return img[y : (y + h), x : (x + w)]
      
  patch = tf.image.resize(bbox2numpy(img, bbox), [112, 112])
  return tf.reshape(patch, (1, 112, 112, 3))


def getPrettyActionHistory(model: ADNET):
  action_hist = tf.reshape(model.action_history, [-1])
  sbuffer = "["
  for i, x in enumerate(action_hist):
    if i > 0 and i % model.ACTION_DIM == 0:
      sbuffer+= "\x1b[35m,\x1b[0m"
    if x == 1:
      sbuffer += "\x1b[35m{0}\x1b[0m".format(int(x))
    else:
      sbuffer += "{0}".format(int(x))
  sbuffer += "]"
  return sbuffer 


def seqReward(action_probs: np.array, actions_taken: List[int], 
              src_bbox: np.array, bboxes: List[np.array], 
              target_bbox: np.array) -> np.array:
    """
    Returns an individual reward per action, as advised by
    https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=8808847
    src_bbox is used solely for the first element of the bboxes list
    """
    assert len(action_probs) == len(actions_taken), "Actions taken ({0}) and Probabilities ({1}) lengths differ".format(len(action_probs), len(actions_taken)) 
    assert len(actions_taken) == len(bboxes), "Actions taken ({0}) and Bboxes ({1}) lengths differ".format(len(actions_taken), len(bboxes)) 

    rewards = np.zeros(len(actions_taken))
    for i, a in enumerate(actions_taken):
      bbox = np.array(bboxes[i])
      prev_bbox = np.array(src_bbox) if i == 0 else np.array(bboxes[i-1])

      ###################### CHANGE REWARD CALCULATION HERE ####################
      rewards[i] = 1 if calculate_IOU(np.array(bboxes[-1]), target_bbox) > 0.7\
                    else -1      
      # if isStop(a):
      #   rewards[i] = 1 if calculate_IOU(bbox, target_bbox) > 0.7 else -1
      # else:
      #   rewards[i] = getNonStopScore(prev_bbox, bbox, target_bbox) 
      ###################### CHANGE REWARD CALCULATION UP ABOVE ################

      
      print("   |->> t={0} {1}-Reward ({2}) for {3}:bbox transition: {4} -> {5} w/ P(a|s)={6} and iou={7} and reward={8}"
            .format(i+1, "Stop" if isStop(a) else "Diff", 
                    np.around(rewards[i], decimals=3), 
                    human_readable_action(a).upper(),
                    np.array2string(prev_bbox, separator=', '),
                    np.array2string(bbox, separator=', '), action_probs[i], 
                    calculate_IOU(bbox, target_bbox), 
                    rewards[i]))
        
    offset_probs = [max(PROB_OFFSET, min(p, 1 - PROB_OFFSET)) for p in action_probs]  # done to prevent 0 reward   
    rewards = -1 * rewards * tf.math.log(offset_probs) 
    print("   |->> Assigned rewards: {0}"
              # .format(np.array2string(np.around(rewards, decimals=3), separator=',')))
              .format(rewards))
    return rewards


def tracking(model: ADNET, img: np.array, bbox: np.array, action_hist: np.array, 
             t: int, target_bbox: np.array, tracking_length: int= MAX_ACTION_SEQ_LIMIT, 
             action_strategy: str= "max"):
    """ 
    Runs tracking until # actions > MAX_ACTIONS_SEQ_LIMIT, STOP is taken, or
    oscillation occurs.
    """

    def _updateDynamicsRoll(model: ADNET, action_hist: np.array, 
                            a: int=8) -> np.array:
      action_hist[model.ACTION_DIM:] = action_hist[:-model.ACTION_DIM]
      action_hist[:model.ACTION_DIM] = 0 
      action_hist[a] = 1
      model.setActionHistory(action_hist)
      if VERBOSE:
        print("         |->> Overwriting action in buffer {0}"
            .format(getPrettyActionHistory(model) if VERBOSE else ""))
      return action_hist

    print("     |->> Beginning tracking for bbox:{0}".format(bbox))    
    patch = getPatch(img, bbox)
    actions_taken, action_probs = [], []
    bboxes = []
    prev_score = None
    while len(actions_taken) < tracking_length:
      isRandomFlag = False
      prev_bbox = bbox.copy()
      
      probs, conf_score = model(patch)
      probs = tf.reshape(probs, (model.ACTION_DIM)) 
      
      a = -1
      if action_strategy == "max":
        a, bbox = selectMaxAction(np.array(img), bbox, probs)
      elif action_strategy == "sample": 
        a, bbox = sampleAction(np.array(img), bbox, probs)
      else:
        raise ValueError("Invalid action_strategy {0} provided"
                    .format(action_strategy))

      prev_iou = calculate_IOU(prev_bbox, target_bbox)
      iou = calculate_IOU(bbox, target_bbox)   
      
      # Select a random action 50% of the time when low confidence in state 
      # (https://github.com/hellbell/ADNet/blob/master/train/tracker_rl.m#L42-L46)
      ###### TODO: try turning the policy v
      # conf_score = tf.reshape(conf_score, (CONF_SCORE_DIM))[1]
      # is_decreased_confidence = prev_score and conf_score < prev_score
      # if is_decreased_confidence and random.uniform(0,1) > 0.5:
      #     a = np.random.randint(model.ACTION_DIM, size=1)[0]
      #     isRandomFlag = True
      # prev_score = tf.squeeze(conf_score)
      if tuple(bbox) in bboxes:
        # OSCILLATION
        print("             |->> Revisiting bbox: {0}. Breaking action sequence"
                  .format(bbox))
        print("             |->> Overriding with STOP"
                .format(iou))
        a, bbox = 8, prev_bbox
      elif prev_iou > iou and prev_iou > 0.7:
        # TRAJECTORY IS WORSENING
        print("             |->> IOU declining: {0}:{1} -> {2}:{3}."
                  .format(prev_bbox, prev_iou, bbox, iou))
        print("             |->> Overriding with STOP"
                .format(iou))
        a, bbox = 8, prev_bbox
      
      a_prob = probs[a] # TODO: action_probs.append(a_prob * DISCOUNT_FACTOR ** len(action_probs))
      action_probs.append(a_prob)
      actions_taken.append(a)
      print("      \x1b[33m|->> #{0}-th {4}Action selection: {1}/{2} (P(a|s) = {3})\x1b[0m"
                .format(t, a, human_readable_action(a).upper(), 
                        np.around(a_prob, decimals=3), 
                        "RANDOM " if isRandomFlag else ""))
      print("         |->> Bounding box moves to: {0}"
                .format(bbox))
      print("         |->> Action Probabilities (ROUNDED): {0}, argmax={1}"
                .format(np.around(probs.numpy(), decimals=3), np.argmax(probs)))
      if VERBOSE:
        print("         |->> Action Probabilities (RAW): {0}, argmax={1}"
                .format(probs.numpy(), np.argmax(probs)))

      # Update the current patch
      patch = getPatch(img, bbox)
      action_hist = _updateDynamicsRoll(model, action_hist, a)

      
      bboxes.append(tuple(bbox))  
      
      # Stopping condition
      if isStop(a):
        print("         |->> Hit a STOP on the {0}-th action!".format(t))
        break  
      
      t += 1

    print("    \x1b[31m|->> Completed tracking\x1b[0m")
    return action_probs, actions_taken, bboxes, action_hist, t


def train(model: ADNET, opt: tf.keras.optimizers.Optimizer, 
          dataset: str, start_frame: int, end_frame: int, 
          action_strategy: str = "max", n_retries: int=1) -> float:
  '''
  Run training for a model on a frame sequence {start_frame, end_frame} 
  n_retries times.
  :param: model: the ADNET model
  :param: opt: optimizer to potimize model with
  :param: dataset: is the dataset path to train from
  :param: start_frame: starting frame of sequence
  :param: end_frame: ending frame of sequence
  :param: action_strategy: set to "max" or "sample" to decide action based
          on policy. max runs an argmax on p(a|s) to decide the action. sample
          selects an action from a normalized p(a|s) distribution (offsetted w/ 
          small noise to ensure possible selection of all actions).
  :param: n_retries: number of times to train on the frame sequence. We tried
          setting this >= 1 and it just made things slower
  :return: returns the average loss
  '''
  if action_strategy == "max" and n_retries > 0:
    # There's no point re-running a trajectory under a deterministic argmax policy
    action_strategy = "sample" 


  gt = get_ground_truths("%s/groundtruth_rect.txt" % d)
  frames = sorted(glob.glob(os.path.join('%s/img' % d, '*.jpg'))) 
  episode_losses = []  
  with tf.GradientTape() as tape:

    prev_start_act, prev_start_prob = None, -1.0 # Used for quick debugging reference
    for i in range(n_retries):
      start_act, start_prob = None, None         # Used for quick debugging reference
      print("\n\x1b[94m####################### EPISODE # {0} ############################\x1b[0m".format(i+1))
      bbox = gt[start_frame]
      print("Starting bounding box for {0}: frames {1}:{2} is {3}.".format(
              dataset, start_frame, end_frame, bbox))
      
      
      t = 1
      seq_losses = []
      action_hist = np.zeros((model.ACTION_DIM * model.K, 1)) 
      for i in range(start_frame+1, end_frame+1):
        target_bbox = gt[i]
        prev_bbox = np.array(bbox, copy=True)

        print("\x1b[34m>> Attempting to reach frame {0} with src: {1} and target: {2}\x1b[0m"
            .format(i, np.array2string(bbox, separator=', '), 
                    np.array2string(target_bbox, separator=', ')))
        img = getFrame(dataset, i) 
        action_probs, taken_actions, bboxes, action_hist, t = \
                                tracking(model, img, bbox, action_hist, t, 
                                         target_bbox, 
                                         tracking_length=MAX_ACTION_SEQ_LIMIT, 
                                         action_strategy=action_strategy)
        bbox = np.array(bboxes[-1])

        print("\x1b[34m>> Calculating frame loss : {0} -> {1} (Target was {2})\x1b[0m".format(
            np.array2string(prev_bbox, separator=', '),
            np.array2string(bbox, separator=', '),
            np.array2string(target_bbox, separator=', ')))
        rewards = seqReward(action_probs, taken_actions, 
                            prev_bbox, bboxes, target_bbox)
        total_frame_loss = tf.reduce_sum(rewards)
        
        print("{0}>> Total frame loss: {1}\x1b[0m".format(
              "\x1b[92m" if total_frame_loss > 0 else "\x1b[31m", 
              total_frame_loss))
        seq_losses.append(total_frame_loss)

        if start_act is None and start_prob is None: # Used for quick debugging reference
          start_act, start_prob = taken_actions[0], action_probs[0]
        
      print("Final bounding box: {0} reached in {1} timesteps (originating from {2}). Target was {3}"
            .format(bbox, t, np.array(gt[start_frame]), np.array(gt[end_frame])))

      episode_loss = tf.reduce_mean(seq_losses) # tf.reduce_sum() was too noisy
      episode_losses.append(episode_loss)
      print("{0}Total Episode Loss: {1} \x1b[0m with starting action {2} (P(a|s)={3}). Previous episode starting action: {4} (P(a|s)={5})"
            .format("\x1b[92m" if episode_loss > 0 else "\x1b[31m", 
                    episode_loss, human_readable_action(start_act), start_prob, 
                    human_readable_action(prev_start_act) if prev_start_act else "N/A", 
                    prev_start_prob))
      print("\n\x1b[94m############# END EPISODE # {0} in t={1} timesteps ################\x1b[0m".format(i+1, t))
      prev_start_act, prev_start_prob = start_act, start_prob 

    ###################### End of gradient tape (Add any final calculations here) ######################
    print("EPISODE LOSSES: {0}".format([l.numpy() for l in episode_losses]))  
    ###################### Exiting of gradient tape (Add any final calculations here) ######################
  
  
  grads = tape.gradient(episode_losses, model.trainable_variables)
  if grads is None:
    # This really shouldn't be here :(. But I've yet to figure out the TF issue: https://stackoverflow.com/questions/56916313/tensorflow-2-0-doesnt-compute-the-gradient/56917148#56917148
    return model, []

  for i in range(len(grads)):
      print("Layer Name: {}, GRAD NORM = {}".format(
      adnet_model.trainable_variables[i].name, tf.norm(grads[i])))
      # TODO: try to scale gradients here
  opt.apply_gradients(zip(grads, model.trainable_variables))
  return model, episode_losses




adnet_model=ADNET()
action_hist = np.zeros(shape = (1,1,1,110))
adnet_model.build(action_hist)
YIFAN_WEIGHTS_PATH = "yifanweights.mat"
weights = hdf5storage.loadmat(YIFAN_WEIGHTS_PATH)
adnet_model = setWeights(adnet_model,weights,weights)
adnet_model.layers[-3].trainable=False
# adnet_model.layers[0].trainable=False
# adnet_model.layers[1].trainable=False
# adnet_model.layers[2].trainable=False
# adnet_model.layers[3].trainable=False
# adnet_model.layers[4].trainable=False
# adnet_model.layers[5].trainable=False

ADAM_OPT = Adam(learning_rate=1e-4)
SGD_OPT = SGD(learning_rate=1e-4, momentum=0.9)
SGDW_OPT = tfa.optimizers.SGDW(weight_decay=0.0005, 
                               learning_rate=1e-4, nesterov=True)

ALL_DATASETS_LIST = glob.glob("adnet_datasets/OTB/*")
FAILURE_THRESHOLD = 0.5


rand_idx = 1
d = ALL_DATASETS_LIST[rand_idx] 
gt = get_ground_truths("%s/groundtruth_rect.txt" % d)
frames = sorted(glob.glob(os.path.join('%s/img' % d, '*.jpg')))


losses = {}
bad_data_log = []
NUM_EPOCHS = 10
L = 10
SEQUENCE_RETRAIN_COUNT = 16
for e in range(NUM_EPOCHS):

  epoch_loss = []
  for i in range(len(frames) - L):

    for _ in range(SEQUENCE_RETRAIN_COUNT):
      print("\n\n#############################################")
      print("Dataset={0} with {1} frames".format(d, len(frames)))
      print("#################################################")
      try:
        start_frame = i
        adnet_model, avg_loss = train(adnet_model, 
                                      ADAM_OPT, d, 
                                      start_frame, start_frame + L, 
                                      action_strategy="sample")
        epoch_loss.append(avg_loss)
        print("#################################################")
        print("#################################################")
      except tf.errors.InvalidArgumentError as e:
        print(e)
        bad_data_log.append("Dataset={0}, frames={1}:{2}\n{3}"
              .format(d, start_frame, start_frame+L, e))
        print("Skipping sequence={0}:{1}".format(start_frame, start_frame+L))

  losses[e] = epoch_loss

print("Training complete")

fig = plt.figure()
for e in losses:
  plt.plot(np.arange(len(losses[e])), losses[e]) 
plt.xlabel('Number of Episodes')
plt.ylabel('Sequence Loss')
# Out:
# Streaming output truncated to the last 5000 lines.
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [391,  67,  26,  24] -> [390,  67,  26,  24] w/ P(a|s)=0.7867507338523865 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [390,  67,  26,  24] -> [392,  67,  26,  24] w/ P(a|s)=0.19550728797912598 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=4 Stop-Reward (-1.0) for STOP:bbox transition: [392,  67,  26,  24] -> [392,  67,  26,  24] w/ P(a|s)=2.825810270223883e-07 and iou=0.6376811594202898 and reward=-1.0
#    |->> Assigned rewards: [-0.20448746 -0.23984382 -1.6321576  -9.2103405 ]
# >> Total frame loss: -11.286828994750977
# >> Attempting to reach frame 121 with src: [392,  67,  26,  24] and target: [388,  72,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0121.jpg
#      |->> Beginning tracking for bbox:[392  67  26  24]
#       |->> #13-th Action selection: 0/LEFT (P(a|s) = 0.8009999990463257)
#          |->> Bounding box moves to: [391  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.801 0.002 0.008 0.184 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #14-th Action selection: 0/LEFT (P(a|s) = 0.7850000262260437)
#          |->> Bounding box moves to: [390  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.785 0.002 0.009 0.198 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #15-th Action selection: 0/LEFT (P(a|s) = 0.7799999713897705)
#          |->> Bounding box moves to: [389  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.78  0.002 0.009 0.204 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #16-th Action selection: 0/LEFT (P(a|s) = 0.7720000147819519)
#          |->> Bounding box moves to: [388  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.772 0.002 0.009 0.211 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #17-th Action selection: 0/LEFT (P(a|s) = 0.7549999952316284)
#          |->> Bounding box moves to: [387  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.755 0.003 0.01  0.226 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [389  67  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #18-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [387  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.741 0.003 0.012 0.237 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#          |->> Hit a STOP on the 18-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [392,  67,  26,  24] -> [387,  67,  26,  24] (Target was [388,  72,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [392,  67,  26,  24] -> [391,  67,  26,  24] w/ P(a|s)=0.8007427453994751 and iou=0.4694408322496749 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [391,  67,  26,  24] -> [390,  67,  26,  24] w/ P(a|s)=0.7849420309066772 and iou=0.5066666666666667 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [390,  67,  26,  24] -> [389,  67,  26,  24] w/ P(a|s)=0.7796196341514587 and iou=0.5458276333789329 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [389,  67,  26,  24] -> [388,  67,  26,  24] w/ P(a|s)=0.7721464037895203 and iou=0.5870786516853933 and reward=-1.0
#    |->> t=5 Diff-Reward (-1.0) for LEFT:bbox transition: [388,  67,  26,  24] -> [387,  67,  26,  24] w/ P(a|s)=0.7550073862075806 and iou=0.5870786516853933 and reward=-1.0
#    |->> t=6 Stop-Reward (-1.0) for STOP:bbox transition: [387,  67,  26,  24] -> [387,  67,  26,  24] w/ P(a|s)=7.504423820137163e-07 and iou=0.5870786516853933 and reward=-1.0
#    |->> Assigned rewards: [-0.22221555 -0.2421454  -0.24894913 -0.2585811  -0.28102773 -9.2103405 ]
# >> Total frame loss: -10.46325969696045
# >> Attempting to reach frame 122 with src: [387,  67,  26,  24] and target: [388,  72,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0122.jpg
#      |->> Beginning tracking for bbox:[387  67  26  24]
#       |->> #18-th Action selection: 0/LEFT (P(a|s) = 0.7730000019073486)
#          |->> Bounding box moves to: [386  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.773 0.003 0.009 0.209 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #19-th Action selection: 2/RIGHT (P(a|s) = 0.010999999940395355)
#          |->> Bounding box moves to: [387  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.747 0.003 0.011 0.233 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [386  67  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #20-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [387  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.786 0.002 0.008 0.198 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#          |->> Hit a STOP on the 20-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [387,  67,  26,  24] -> [387,  67,  26,  24] (Target was [388,  72,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [387,  67,  26,  24] -> [386,  67,  26,  24] w/ P(a|s)=0.7725440263748169 and iou=0.5870786516853933 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for RIGHT:bbox transition: [386,  67,  26,  24] -> [387,  67,  26,  24] w/ P(a|s)=0.010997902601957321 and iou=0.5870786516853933 and reward=-1.0
#    |->> t=3 Stop-Reward (-1.0) for STOP:bbox transition: [387,  67,  26,  24] -> [387,  67,  26,  24] w/ P(a|s)=5.032592866882624e-07 and iou=0.5870786516853933 and reward=-1.0
#    |->> Assigned rewards: [-0.2580663 -4.510051  -9.2103405]
# >> Total frame loss: -13.9784574508667
# >> Attempting to reach frame 123 with src: [387,  67,  26,  24] and target: [386,  73,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0123.jpg
#      |->> Beginning tracking for bbox:[387  67  26  24]
#       |->> #20-th Action selection: 0/LEFT (P(a|s) = 0.7580000162124634)
#          |->> Bounding box moves to: [386  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.758 0.003 0.01  0.222 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #21-th Action selection: 3/2X RIGHT (P(a|s) = 0.23000000417232513)
#          |->> Bounding box moves to: [388  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.749 0.003 0.011 0.23  0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #22-th Action selection: 0/LEFT (P(a|s) = 0.7760000228881836)
#          |->> Bounding box moves to: [387  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.776 0.003 0.01  0.205 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #23-th Action selection: 3/2X RIGHT (P(a|s) = 0.22599999606609344)
#          |->> Bounding box moves to: [389  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.753 0.003 0.011 0.226 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [388  67  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #24-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [389  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.78  0.003 0.01  0.199 0.002 0.    0.    0.002 0.    0.004 0.001], argmax=0
#          |->> Hit a STOP on the 24-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [387,  67,  26,  24] -> [389,  67,  26,  24] (Target was [386,  73,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [387,  67,  26,  24] -> [386,  67,  26,  24] w/ P(a|s)=0.7583250403404236 and iou=0.5395095367847411 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [386,  67,  26,  24] -> [388,  67,  26,  24] w/ P(a|s)=0.2300918996334076 and iou=0.4675324675324675 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [388,  67,  26,  24] -> [387,  67,  26,  24] w/ P(a|s)=0.7755749225616455 and iou=0.5026595744680851 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [387,  67,  26,  24] -> [389,  67,  26,  24] w/ P(a|s)=0.2261601984500885 and iou=0.434010152284264 and reward=-1.0
#    |->> t=5 Stop-Reward (-1.0) for STOP:bbox transition: [389,  67,  26,  24] -> [389,  67,  26,  24] w/ P(a|s)=1.012597181215824e-06 and iou=0.434010152284264 and reward=-1.0
#    |->> Assigned rewards: [-0.27664316 -1.4692764  -0.2541507  -1.4865117  -9.2103405 ]
# >> Total frame loss: -12.696922302246094
# >> Attempting to reach frame 124 with src: [389,  67,  26,  24] and target: [386,  73,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0124.jpg
#      |->> Beginning tracking for bbox:[389  67  26  24]
#       |->> #24-th Action selection: 0/LEFT (P(a|s) = 0.7400000095367432)
#          |->> Bounding box moves to: [388  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.74  0.005 0.015 0.228 0.002 0.    0.001 0.002 0.    0.005 0.001], argmax=0
#       |->> #25-th Action selection: 0/LEFT (P(a|s) = 0.7409999966621399)
#          |->> Bounding box moves to: [387  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.741 0.005 0.014 0.229 0.002 0.    0.001 0.002 0.    0.005 0.001], argmax=0
#       |->> #26-th Action selection: 0/LEFT (P(a|s) = 0.7450000047683716)
#          |->> Bounding box moves to: [386  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.745 0.004 0.012 0.231 0.002 0.    0.    0.002 0.    0.004 0.001], argmax=0
#       |->> #27-th Action selection: 0/LEFT (P(a|s) = 0.7419999837875366)
#          |->> Bounding box moves to: [385  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.742 0.003 0.011 0.236 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [387  67  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #28-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [385  67  26  24]
#          |->> Action Probabilities (ROUNDED): [0.741 0.003 0.011 0.238 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#          |->> Hit a STOP on the 28-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [389,  67,  26,  24] -> [385,  67,  26,  24] (Target was [386,  73,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [389,  67,  26,  24] -> [388,  67,  26,  24] w/ P(a|s)=0.7397794723510742 and iou=0.4675324675324675 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [388,  67,  26,  24] -> [387,  67,  26,  24] w/ P(a|s)=0.740506112575531 and iou=0.5026595744680851 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [387,  67,  26,  24] -> [386,  67,  26,  24] w/ P(a|s)=0.7445604205131531 and iou=0.5395095367847411 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [386,  67,  26,  24] -> [385,  67,  26,  24] w/ P(a|s)=0.7415278553962708 and iou=0.5395095367847411 and reward=-1.0
#    |->> t=5 Stop-Reward (-1.0) for STOP:bbox transition: [385,  67,  26,  24] -> [385,  67,  26,  24] w/ P(a|s)=5.736510502174497e-07 and iou=0.5395095367847411 and reward=-1.0
#    |->> Assigned rewards: [-0.30140314 -0.3004214  -0.29496127 -0.29904255 -9.2103405 ]
# >> Total frame loss: -10.406168937683105
# Final bounding box: [385  67  26  24] reached in 28 timesteps (originating from [398  67  26  24]). Target was [386  73  22  23]
# Total Episode Loss: -3.185676097869873  with starting action LEFT (P(a|s)=0.824145495891571). Previous episode starting action: N/A (P(a|s)=-1.0)
#
# ############# END EPISODE # 125 in t=28 timesteps ################
# EPISODE LOSSES: [-3.185676]
# Layer Name: conv_1/kernel:0, GRAD NORM = 1.452425479888916
# Layer Name: conv_1/bias:0, GRAD NORM = 0.0005181177984923124
# Layer Name: conv_2/kernel:0, GRAD NORM = 1.5138356685638428
# Layer Name: conv_2/bias:0, GRAD NORM = 0.00024821507395245135
# Layer Name: conv_3/kernel:0, GRAD NORM = 1.8589375019073486
# Layer Name: conv_3/bias:0, GRAD NORM = 0.0002979363489430398
# Layer Name: fc1/kernel:0, GRAD NORM = 2.3700809478759766
# Layer Name: fc1/bias:0, GRAD NORM = 0.00036907076719217
# Layer Name: fc2/kernel:0, GRAD NORM = 19.837827682495117
# Layer Name: fc2/bias:0, GRAD NORM = 0.007213271223008633
# Layer Name: fc3/kernel:0, GRAD NORM = 42.186309814453125
# Layer Name: fc3/bias:0, GRAD NORM = 0.1767164021730423
# #################################################
# #################################################
#
#
# #############################################
# Dataset=adnet_datasets/OTB/Biker with 142 frames
# #################################################
#
# ####################### EPISODE # 1 ############################
# Starting bounding box for adnet_datasets/OTB/Biker: frames 115:125 is [397  69  26  24].
# >> Attempting to reach frame 116 with src: [397,  69,  26,  24] and target: [396,  69,  26,  24]
# Frame path: adnet_datasets/OTB/Biker/img/0116.jpg
#      |->> Beginning tracking for bbox:[397  69  26  24]
#              |->> IOU declining: [397  69  26  24]:0.9259259259259259 -> [399  69  26  24]:0.7931034482758621.
#              |->> Overriding with STOP
#       |->> #1-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [397  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.804 0.001 0.007 0.184 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#          |->> Hit a STOP on the 1-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [397,  69,  26,  24] -> [397,  69,  26,  24] (Target was [396,  69,  26,  24])
#    |->> t=1 Stop-Reward (1.0) for STOP:bbox transition: [397,  69,  26,  24] -> [397,  69,  26,  24] w/ P(a|s)=2.091749990995595e-07 and iou=0.9259259259259259 and reward=1.0
#    |->> Assigned rewards: [9.2103405]
# >> Total frame loss: 9.21034049987793
# >> Attempting to reach frame 117 with src: [397,  69,  26,  24] and target: [396,  69,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0117.jpg
#      |->> Beginning tracking for bbox:[397  69  26  24]
#       |->> #1-th Action selection: 0/LEFT (P(a|s) = 0.8109999895095825)
#          |->> Bounding box moves to: [396  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.811 0.002 0.007 0.176 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#       |->> #2-th Action selection: 0/LEFT (P(a|s) = 0.7879999876022339)
#          |->> Bounding box moves to: [395  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.788 0.002 0.008 0.197 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#              |->> Revisiting bbox: [396  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #3-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [395  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.786 0.002 0.008 0.2   0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 3-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [397,  69,  26,  24] -> [395,  69,  26,  24] (Target was [396,  69,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [397,  69,  26,  24] -> [396,  69,  26,  24] w/ P(a|s)=0.8111009001731873 and iou=0.8108974358974359 and reward=1.0
#    |->> t=2 Diff-Reward (1.0) for LEFT:bbox transition: [396,  69,  26,  24] -> [395,  69,  26,  24] w/ P(a|s)=0.7882460355758667 and iou=0.8108974358974359 and reward=1.0
#    |->> t=3 Stop-Reward (1.0) for STOP:bbox transition: [395,  69,  26,  24] -> [395,  69,  26,  24] w/ P(a|s)=2.8097770155000035e-07 and iou=0.8108974358974359 and reward=1.0
#    |->> Assigned rewards: [0.20936282 0.237945   9.2103405 ]
# >> Total frame loss: 9.657648086547852
# >> Attempting to reach frame 118 with src: [395,  69,  26,  24] and target: [396,  69,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0118.jpg
#      |->> Beginning tracking for bbox:[395  69  26  24]
#       |->> #3-th Action selection: 0/LEFT (P(a|s) = 0.800000011920929)
#          |->> Bounding box moves to: [394  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.8   0.002 0.007 0.187 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#       |->> #4-th Action selection: 3/2X RIGHT (P(a|s) = 0.210999995470047)
#          |->> Bounding box moves to: [396  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.774 0.002 0.009 0.211 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#       |->> #5-th Action selection: 0/LEFT (P(a|s) = 0.8119999766349792)
#          |->> Bounding box moves to: [395  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.812 0.001 0.007 0.177 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#              |->> Revisiting bbox: [394  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #6-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [395  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.784 0.002 0.009 0.201 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#          |->> Hit a STOP on the 6-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [395,  69,  26,  24] -> [395,  69,  26,  24] (Target was [396,  69,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [395,  69,  26,  24] -> [394,  69,  26,  24] w/ P(a|s)=0.8001580238342285 and iou=0.8108974358974359 and reward=1.0
#    |->> t=2 Diff-Reward (1.0) for 2X RIGHT:bbox transition: [394,  69,  26,  24] -> [396,  69,  26,  24] w/ P(a|s)=0.21138106286525726 and iou=0.8108974358974359 and reward=1.0
#    |->> t=3 Diff-Reward (1.0) for LEFT:bbox transition: [396,  69,  26,  24] -> [395,  69,  26,  24] w/ P(a|s)=0.8118743896484375 and iou=0.8108974358974359 and reward=1.0
#    |->> t=4 Stop-Reward (1.0) for STOP:bbox transition: [395,  69,  26,  24] -> [395,  69,  26,  24] w/ P(a|s)=2.489238681846473e-07 and iou=0.8108974358974359 and reward=1.0
#    |->> Assigned rewards: [0.22294605 1.5540928  0.20840964 9.2103405 ]
# >> Total frame loss: 11.195788383483887
# >> Attempting to reach frame 119 with src: [395,  69,  26,  24] and target: [394,  71,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0119.jpg
#      |->> Beginning tracking for bbox:[395  69  26  24]
#       |->> #6-th Action selection: 0/LEFT (P(a|s) = 0.8080000281333923)
#          |->> Bounding box moves to: [394  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.808 0.002 0.007 0.179 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#              |->> IOU declining: [394  69  26  24]:0.7492260061919505 -> [396  69  26  24]:0.6376811594202898.
#              |->> Overriding with STOP
#       |->> #7-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [394  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.774 0.002 0.009 0.21  0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 7-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [395,  69,  26,  24] -> [394,  69,  26,  24] (Target was [394,  71,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [395,  69,  26,  24] -> [394,  69,  26,  24] w/ P(a|s)=0.8083381652832031 and iou=0.7492260061919505 and reward=1.0
#    |->> t=2 Stop-Reward (1.0) for STOP:bbox transition: [394,  69,  26,  24] -> [394,  69,  26,  24] w/ P(a|s)=3.0884638135830755e-07 and iou=0.7492260061919505 and reward=1.0
#    |->> Assigned rewards: [0.21277478 9.2103405 ]
# >> Total frame loss: 9.423115730285645
# >> Attempting to reach frame 120 with src: [394,  69,  26,  24] and target: [392,  71,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0120.jpg
#      |->> Beginning tracking for bbox:[394  69  26  24]
#       |->> #7-th Action selection: 0/LEFT (P(a|s) = 0.796999990940094)
#          |->> Bounding box moves to: [393  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.797 0.002 0.007 0.189 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#       |->> #8-th Action selection: 0/LEFT (P(a|s) = 0.7680000066757202)
#          |->> Bounding box moves to: [392  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.768 0.002 0.009 0.218 0.001 0.    0.    0.001 0.    0.002 0.   ], argmax=0
#       |->> #9-th Action selection: 0/LEFT (P(a|s) = 0.7720000147819519)
#          |->> Bounding box moves to: [391  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.772 0.002 0.009 0.213 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #10-th Action selection: 0/LEFT (P(a|s) = 0.7609999775886536)
#          |->> Bounding box moves to: [390  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.761 0.002 0.009 0.223 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #11-th Action selection: 0/LEFT (P(a|s) = 0.7559999823570251)
#          |->> Bounding box moves to: [389  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.756 0.002 0.009 0.228 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#              |->> Revisiting bbox: [391  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #12-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [389  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.744 0.002 0.01  0.239 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 12-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [394,  69,  26,  24] -> [389,  69,  26,  24] (Target was [392,  71,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [394,  69,  26,  24] -> [393,  69,  26,  24] w/ P(a|s)=0.7973476648330688 and iou=0.6916167664670658 and reward=1.0
#    |->> t=2 Diff-Reward (1.0) for LEFT:bbox transition: [393,  69,  26,  24] -> [392,  69,  26,  24] w/ P(a|s)=0.7675850987434387 and iou=0.7492260061919505 and reward=1.0
#    |->> t=3 Diff-Reward (1.0) for LEFT:bbox transition: [392,  69,  26,  24] -> [391,  69,  26,  24] w/ P(a|s)=0.7720262408256531 and iou=0.7492260061919505 and reward=1.0
#    |->> t=4 Diff-Reward (1.0) for LEFT:bbox transition: [391,  69,  26,  24] -> [390,  69,  26,  24] w/ P(a|s)=0.7613681554794312 and iou=0.7492260061919505 and reward=1.0
#    |->> t=5 Diff-Reward (1.0) for LEFT:bbox transition: [390,  69,  26,  24] -> [389,  69,  26,  24] w/ P(a|s)=0.7561171650886536 and iou=0.7492260061919505 and reward=1.0
#    |->> t=6 Stop-Reward (1.0) for STOP:bbox transition: [389,  69,  26,  24] -> [389,  69,  26,  24] w/ P(a|s)=3.702993467413762e-07 and iou=0.7492260061919505 and reward=1.0
#    |->> Assigned rewards: [0.22646448 0.26450592 0.25873673 0.27263826 0.27955893 9.2103405 ]
# >> Total frame loss: 10.512245178222656
# >> Attempting to reach frame 121 with src: [389,  69,  26,  24] and target: [388,  72,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0121.jpg
#      |->> Beginning tracking for bbox:[389  69  26  24]
#       |->> #12-th Action selection: 3/2X RIGHT (P(a|s) = 0.22599999606609344)
#          |->> Bounding box moves to: [391  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.758 0.002 0.009 0.226 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #13-th Action selection: 0/LEFT (P(a|s) = 0.7720000147819519)
#          |->> Bounding box moves to: [390  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.772 0.002 0.009 0.212 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #14-th Action selection: 0/LEFT (P(a|s) = 0.753000020980835)
#          |->> Bounding box moves to: [389  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.753 0.002 0.01  0.229 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #15-th Action selection: 0/LEFT (P(a|s) = 0.753000020980835)
#          |->> Bounding box moves to: [388  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.753 0.002 0.01  0.23  0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#              |->> Revisiting bbox: [390  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #16-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [388  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.738 0.003 0.011 0.244 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 16-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [389,  69,  26,  24] -> [388,  69,  26,  24] (Target was [388,  72,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [389,  69,  26,  24] -> [391,  69,  26,  24] w/ P(a|s)=0.22619324922561646 and iou=0.5458276333789329 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [391,  69,  26,  24] -> [390,  69,  26,  24] w/ P(a|s)=0.7723208069801331 and iou=0.5915492957746479 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [390,  69,  26,  24] -> [389,  69,  26,  24] w/ P(a|s)=0.7527674436569214 and iou=0.6400580551523948 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [389,  69,  26,  24] -> [388,  69,  26,  24] w/ P(a|s)=0.7528802752494812 and iou=0.6916167664670658 and reward=-1.0
#    |->> t=5 Stop-Reward (-1.0) for STOP:bbox transition: [388,  69,  26,  24] -> [388,  69,  26,  24] w/ P(a|s)=4.229425769608497e-07 and iou=0.6916167664670658 and reward=-1.0
#    |->> Assigned rewards: [-1.4863656  -0.25835526 -0.28399894 -0.28384906 -9.2103405 ]
# >> Total frame loss: -11.522909164428711
# >> Attempting to reach frame 122 with src: [388,  69,  26,  24] and target: [388,  72,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0122.jpg
#      |->> Beginning tracking for bbox:[388  69  26  24]
#       |->> #16-th Action selection: 0/LEFT (P(a|s) = 0.7639999985694885)
#          |->> Bounding box moves to: [387  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.764 0.002 0.01  0.217 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #17-th Action selection: 0/LEFT (P(a|s) = 0.734000027179718)
#          |->> Bounding box moves to: [386  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.734 0.003 0.012 0.245 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #18-th Action selection: 0/LEFT (P(a|s) = 0.7429999709129333)
#          |->> Bounding box moves to: [385  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.743 0.003 0.011 0.238 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #19-th Action selection: 0/LEFT (P(a|s) = 0.7229999899864197)
#          |->> Bounding box moves to: [384  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.723 0.003 0.012 0.255 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [386  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #20-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [384  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.711 0.004 0.014 0.263 0.002 0.    0.    0.001 0.    0.003 0.001], argmax=0
#          |->> Hit a STOP on the 20-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [388,  69,  26,  24] -> [384,  69,  26,  24] (Target was [388,  72,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [388,  69,  26,  24] -> [387,  69,  26,  24] w/ P(a|s)=0.7644443511962891 and iou=0.6916167664670658 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [387,  69,  26,  24] -> [386,  69,  26,  24] w/ P(a|s)=0.734017014503479 and iou=0.6916167664670658 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [386,  69,  26,  24] -> [385,  69,  26,  24] w/ P(a|s)=0.742990255355835 and iou=0.6916167664670658 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [385,  69,  26,  24] -> [384,  69,  26,  24] w/ P(a|s)=0.7232195138931274 and iou=0.6916167664670658 and reward=-1.0
#    |->> t=5 Stop-Reward (-1.0) for STOP:bbox transition: [384,  69,  26,  24] -> [384,  69,  26,  24] w/ P(a|s)=1.0312418226021691e-06 and iou=0.6916167664670658 and reward=-1.0
#    |->> Assigned rewards: [-0.26860604 -0.30922306 -0.29707235 -0.3240425  -9.2103405 ]
# >> Total frame loss: -10.409284591674805
# >> Attempting to reach frame 123 with src: [384,  69,  26,  24] and target: [386,  73,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0123.jpg
#      |->> Beginning tracking for bbox:[384  69  26  24]
#       |->> #20-th Action selection: 3/2X RIGHT (P(a|s) = 0.23800000548362732)
#          |->> Bounding box moves to: [386  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.742 0.003 0.011 0.238 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #21-th Action selection: 0/LEFT (P(a|s) = 0.7540000081062317)
#          |->> Bounding box moves to: [385  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.754 0.003 0.011 0.225 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #22-th Action selection: 0/LEFT (P(a|s) = 0.7409999966621399)
#          |->> Bounding box moves to: [384  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.741 0.003 0.012 0.238 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #23-th Action selection: 0/LEFT (P(a|s) = 0.7310000061988831)
#          |->> Bounding box moves to: [383  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.731 0.003 0.012 0.247 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #24-th Action selection: 1/2X LEFT (P(a|s) = 0.004000000189989805)
#          |->> Bounding box moves to: [381  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.71  0.004 0.014 0.264 0.002 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #25-th Action selection: 0/LEFT (P(a|s) = 0.6970000267028809)
#          |->> Bounding box moves to: [380  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.697 0.005 0.015 0.272 0.002 0.    0.001 0.002 0.    0.004 0.001], argmax=0
#       |->> #26-th Action selection: 0/LEFT (P(a|s) = 0.6499999761581421)
#          |->> Bounding box moves to: [379  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.65  0.006 0.021 0.309 0.003 0.001 0.001 0.003 0.    0.005 0.002], argmax=0
#              |->> Revisiting bbox: [381  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #27-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [379  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.637 0.008 0.023 0.315 0.003 0.001 0.001 0.003 0.    0.007 0.002], argmax=0
#          |->> Hit a STOP on the 27-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [384,  69,  26,  24] -> [379,  69,  26,  24] (Target was [386,  73,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [384,  69,  26,  24] -> [386,  69,  26,  24] w/ P(a|s)=0.23788464069366455 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [386,  69,  26,  24] -> [385,  69,  26,  24] w/ P(a|s)=0.7540356516838074 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [385,  69,  26,  24] -> [384,  69,  26,  24] w/ P(a|s)=0.7405707240104675 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [384,  69,  26,  24] -> [383,  69,  26,  24] w/ P(a|s)=0.7305948734283447 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=5 Diff-Reward (-1.0) for 2X LEFT:bbox transition: [383,  69,  26,  24] -> [381,  69,  26,  24] w/ P(a|s)=0.003724893555045128 and iou=0.5915492957746479 and reward=-1.0
#    |->> t=6 Diff-Reward (-1.0) for LEFT:bbox transition: [381,  69,  26,  24] -> [380,  69,  26,  24] w/ P(a|s)=0.6972593665122986 and iou=0.547945205479452 and reward=-1.0
#    |->> t=7 Diff-Reward (-1.0) for LEFT:bbox transition: [380,  69,  26,  24] -> [379,  69,  26,  24] w/ P(a|s)=0.6501816511154175 and iou=0.5066666666666667 and reward=-1.0
#    |->> t=8 Stop-Reward (-1.0) for STOP:bbox transition: [379,  69,  26,  24] -> [379,  69,  26,  24] w/ P(a|s)=5.9430972214613575e-06 and iou=0.5066666666666667 and reward=-1.0
#    |->> Assigned rewards: [-1.4359695  -0.28231564 -0.30033416 -0.31389618 -5.592717   -0.36059782
#  -0.4305035  -9.2103405 ]
# >> Total frame loss: -17.926673889160156
# >> Attempting to reach frame 124 with src: [379,  69,  26,  24] and target: [386,  73,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0124.jpg
#      |->> Beginning tracking for bbox:[379  69  26  24]
#       |->> #27-th Action selection: 0/LEFT (P(a|s) = 0.6679999828338623)
#          |->> Bounding box moves to: [378  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.668 0.006 0.019 0.293 0.002 0.001 0.001 0.003 0.    0.006 0.002], argmax=0
#       |->> #28-th Action selection: 0/LEFT (P(a|s) = 0.621999979019165)
#          |->> Bounding box moves to: [377  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.622 0.008 0.025 0.327 0.003 0.001 0.001 0.004 0.    0.007 0.002], argmax=0
#       |->> #29-th Action selection: 3/2X RIGHT (P(a|s) = 0.335999995470047)
#          |->> Bounding box moves to: [379  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.601 0.011 0.028 0.336 0.004 0.001 0.001 0.005 0.    0.009 0.003], argmax=0
#       |->> #30-th Action selection: 2/RIGHT (P(a|s) = 0.01899999938905239)
#          |->> Bounding box moves to: [380  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.673 0.006 0.019 0.288 0.002 0.001 0.001 0.003 0.    0.005 0.002], argmax=0
#       |->> #31-th Action selection: 3/2X RIGHT (P(a|s) = 0.2619999945163727)
#          |->> Bounding box moves to: [382  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.708 0.005 0.014 0.262 0.002 0.001 0.001 0.002 0.    0.004 0.001], argmax=0
#       |->> #32-th Action selection: 3/2X RIGHT (P(a|s) = 0.23800000548362732)
#          |->> Bounding box moves to: [384  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.738 0.004 0.013 0.238 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #33-th Action selection: 0/LEFT (P(a|s) = 0.7670000195503235)
#          |->> Bounding box moves to: [383  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.767 0.003 0.011 0.212 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [382  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #34-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [383  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.744 0.003 0.013 0.232 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#          |->> Hit a STOP on the 34-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [379,  69,  26,  24] -> [383,  69,  26,  24] (Target was [386,  73,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [379,  69,  26,  24] -> [378,  69,  26,  24] w/ P(a|s)=0.6680828332901001 and iou=0.4675324675324675 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [378,  69,  26,  24] -> [377,  69,  26,  24] w/ P(a|s)=0.6220467686653137 and iou=0.43037974683544306 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [377,  69,  26,  24] -> [379,  69,  26,  24] w/ P(a|s)=0.3364778459072113 and iou=0.5066666666666667 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for RIGHT:bbox transition: [379,  69,  26,  24] -> [380,  69,  26,  24] w/ P(a|s)=0.018710767850279808 and iou=0.547945205479452 and reward=-1.0
#    |->> t=5 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [380,  69,  26,  24] -> [382,  69,  26,  24] w/ P(a|s)=0.2618282735347748 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=6 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [382,  69,  26,  24] -> [384,  69,  26,  24] w/ P(a|s)=0.23774708807468414 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=7 Diff-Reward (-1.0) for LEFT:bbox transition: [384,  69,  26,  24] -> [383,  69,  26,  24] w/ P(a|s)=0.7668504118919373 and iou=0.6376811594202898 and reward=-1.0
#    |->> t=8 Stop-Reward (-1.0) for STOP:bbox transition: [383,  69,  26,  24] -> [383,  69,  26,  24] w/ P(a|s)=8.663757853355492e-07 and iou=0.6376811594202898 and reward=-1.0
#    |->> Assigned rewards: [-0.4033431  -0.47474    -1.0892229  -3.978656   -1.3400664  -1.4365479
#  -0.26546353 -9.2103405 ]
# >> Total frame loss: -18.198379516601562
# >> Attempting to reach frame 125 with src: [383,  69,  26,  24] and target: [386,  74,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0125.jpg
#      |->> Beginning tracking for bbox:[383  69  26  24]
#       |->> #34-th Action selection: 0/LEFT (P(a|s) = 0.7689999938011169)
#          |->> Bounding box moves to: [382  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.769 0.003 0.01  0.211 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #35-th Action selection: 0/LEFT (P(a|s) = 0.7250000238418579)
#          |->> Bounding box moves to: [381  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.725 0.004 0.013 0.249 0.001 0.    0.    0.002 0.    0.003 0.001], argmax=0
#       |->> #36-th Action selection: 0/LEFT (P(a|s) = 0.7170000076293945)
#          |->> Bounding box moves to: [380  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.717 0.004 0.015 0.254 0.002 0.    0.    0.002 0.    0.004 0.001], argmax=0
#              |->> Revisiting bbox: [382  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #37-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [380  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.683 0.006 0.018 0.282 0.002 0.001 0.001 0.002 0.    0.005 0.002], argmax=0
#          |->> Hit a STOP on the 37-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [383,  69,  26,  24] -> [380,  69,  26,  24] (Target was [386,  74,  22,  23])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [383,  69,  26,  24] -> [382,  69,  26,  24] w/ P(a|s)=0.7689459323883057 and iou=0.5870786516853933 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [382,  69,  26,  24] -> [381,  69,  26,  24] w/ P(a|s)=0.7254531979560852 and iou=0.5458276333789329 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [381,  69,  26,  24] -> [380,  69,  26,  24] w/ P(a|s)=0.717138946056366 and iou=0.5066666666666667 and reward=-1.0
#    |->> t=4 Stop-Reward (-1.0) for STOP:bbox transition: [380,  69,  26,  24] -> [380,  69,  26,  24] w/ P(a|s)=2.6250959308526944e-06 and iou=0.5066666666666667 and reward=-1.0
#    |->> Assigned rewards: [-0.26273462 -0.32095873 -0.33248568 -9.2103405 ]
# >> Total frame loss: -10.126519203186035
# Final bounding box: [380  69  26  24] reached in 37 timesteps (originating from [397  69  26  24]). Target was [386  74  22  23]
# Total Episode Loss: -1.8184627294540405  with starting action STOP (P(a|s)=2.091749990995595e-07). Previous episode starting action: N/A (P(a|s)=-1.0)
#
# ############# END EPISODE # 126 in t=37 timesteps ################
# EPISODE LOSSES: [-1.8184627]
# Layer Name: conv_1/kernel:0, GRAD NORM = 2.543182134628296
# Layer Name: conv_1/bias:0, GRAD NORM = 0.000990481348708272
# Layer Name: conv_2/kernel:0, GRAD NORM = 2.550204277038574
# Layer Name: conv_2/bias:0, GRAD NORM = 0.00044483845704235137
# Layer Name: conv_3/kernel:0, GRAD NORM = 2.9727671146392822
# Layer Name: conv_3/bias:0, GRAD NORM = 0.0005136682302691042
# Layer Name: fc1/kernel:0, GRAD NORM = 3.2125627994537354
# Layer Name: fc1/bias:0, GRAD NORM = 0.0005594838294200599
# Layer Name: fc2/kernel:0, GRAD NORM = 18.807126998901367
# Layer Name: fc2/bias:0, GRAD NORM = 0.008132856339216232
# Layer Name: fc3/kernel:0, GRAD NORM = 37.09911346435547
# Layer Name: fc3/bias:0, GRAD NORM = 0.1810465008020401
# #################################################
# #################################################
#
#
# #############################################
# Dataset=adnet_datasets/OTB/Biker with 142 frames
# #################################################
#
# ####################### EPISODE # 1 ############################
# Starting bounding box for adnet_datasets/OTB/Biker: frames 116:126 is [396  69  26  24].
# >> Attempting to reach frame 117 with src: [396,  69,  26,  24] and target: [396,  69,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0117.jpg
#      |->> Beginning tracking for bbox:[396  69  26  24]
#       |->> #1-th Action selection: 0/LEFT (P(a|s) = 0.7820000052452087)
#          |->> Bounding box moves to: [395  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.782 0.002 0.008 0.204 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #2-th Action selection: 0/LEFT (P(a|s) = 0.7549999952316284)
#          |->> Bounding box moves to: [394  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.755 0.002 0.01  0.227 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #3-th Action selection: 0/LEFT (P(a|s) = 0.7450000047683716)
#          |->> Bounding box moves to: [393  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.745 0.002 0.01  0.237 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #4-th Action selection: 0/LEFT (P(a|s) = 0.7210000157356262)
#          |->> Bounding box moves to: [392  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.721 0.003 0.012 0.258 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> IOU declining: [392  69  26  24]:0.8108974358974359 -> [391  69  26  24]:0.7465224111282844.
#              |->> Overriding with STOP
#       |->> #5-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [392  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.702 0.003 0.014 0.273 0.002 0.    0.    0.001 0.    0.003 0.001], argmax=0
#          |->> Hit a STOP on the 5-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [396,  69,  26,  24] -> [392,  69,  26,  24] (Target was [396,  69,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [396,  69,  26,  24] -> [395,  69,  26,  24] w/ P(a|s)=0.781586229801178 and iou=0.8108974358974359 and reward=1.0
#    |->> t=2 Diff-Reward (1.0) for LEFT:bbox transition: [395,  69,  26,  24] -> [394,  69,  26,  24] w/ P(a|s)=0.7554824948310852 and iou=0.8108974358974359 and reward=1.0
#    |->> t=3 Diff-Reward (1.0) for LEFT:bbox transition: [394,  69,  26,  24] -> [393,  69,  26,  24] w/ P(a|s)=0.7446126341819763 and iou=0.8108974358974359 and reward=1.0
#    |->> t=4 Diff-Reward (1.0) for LEFT:bbox transition: [393,  69,  26,  24] -> [392,  69,  26,  24] w/ P(a|s)=0.7205682992935181 and iou=0.8108974358974359 and reward=1.0
#    |->> t=5 Stop-Reward (1.0) for STOP:bbox transition: [392,  69,  26,  24] -> [392,  69,  26,  24] w/ P(a|s)=1.0374906196375377e-06 and iou=0.8108974358974359 and reward=1.0
#    |->> Assigned rewards: [0.2464298  0.28039867 0.29489115 0.32771507 9.2103405 ]
# >> Total frame loss: 10.35977554321289
# >> Attempting to reach frame 118 with src: [392,  69,  26,  24] and target: [396,  69,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0118.jpg
#      |->> Beginning tracking for bbox:[392  69  26  24]
#              |->> IOU declining: [392  69  26  24]:0.8108974358974359 -> [391  69  26  24]:0.7465224111282844.
#              |->> Overriding with STOP
#       |->> #5-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [392  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.739 0.002 0.01  0.243 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 5-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [392,  69,  26,  24] -> [392,  69,  26,  24] (Target was [396,  69,  22,  23])
#    |->> t=1 Stop-Reward (1.0) for STOP:bbox transition: [392,  69,  26,  24] -> [392,  69,  26,  24] w/ P(a|s)=4.794128471985459e-07 and iou=0.8108974358974359 and reward=1.0
#    |->> Assigned rewards: [9.2103405]
# >> Total frame loss: 9.21034049987793
# >> Attempting to reach frame 119 with src: [392,  69,  26,  24] and target: [394,  71,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0119.jpg
#      |->> Beginning tracking for bbox:[392  69  26  24]
#       |->> #5-th Action selection: 0/LEFT (P(a|s) = 0.7419999837875366)
#          |->> Bounding box moves to: [391  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.742 0.002 0.01  0.24  0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#       |->> #6-th Action selection: 0/LEFT (P(a|s) = 0.7120000123977661)
#          |->> Bounding box moves to: [390  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.712 0.003 0.012 0.268 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#       |->> #7-th Action selection: 3/2X RIGHT (P(a|s) = 0.28299999237060547)
#          |->> Bounding box moves to: [392  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.693 0.003 0.013 0.283 0.001 0.    0.    0.001 0.    0.003 0.001], argmax=0
#              |->> Revisiting bbox: [391  69  26  24]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #8-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [392  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.749 0.002 0.01  0.234 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 8-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [392,  69,  26,  24] -> [392,  69,  26,  24] (Target was [394,  71,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [392,  69,  26,  24] -> [391,  69,  26,  24] w/ P(a|s)=0.7421563267707825 and iou=0.7492260061919505 and reward=1.0
#    |->> t=2 Diff-Reward (1.0) for LEFT:bbox transition: [391,  69,  26,  24] -> [390,  69,  26,  24] w/ P(a|s)=0.711851179599762 and iou=0.7492260061919505 and reward=1.0
#    |->> t=3 Diff-Reward (1.0) for 2X RIGHT:bbox transition: [390,  69,  26,  24] -> [392,  69,  26,  24] w/ P(a|s)=0.2829819321632385 and iou=0.7492260061919505 and reward=1.0
#    |->> t=4 Stop-Reward (1.0) for STOP:bbox transition: [392,  69,  26,  24] -> [392,  69,  26,  24] w/ P(a|s)=4.2409234879414726e-07 and iou=0.7492260061919505 and reward=1.0
#    |->> Assigned rewards: [0.29819536 0.3398864  1.2623723  9.2103405 ]
# >> Total frame loss: 11.110794067382812
# >> Attempting to reach frame 120 with src: [392,  69,  26,  24] and target: [392,  71,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0120.jpg
#      |->> Beginning tracking for bbox:[392  69  26  24]
#       |->> #8-th Action selection: 0/LEFT (P(a|s) = 0.75)
#          |->> Bounding box moves to: [391  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.75  0.002 0.01  0.233 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#              |->> IOU declining: [391  69  26  24]:0.7492260061919505 -> [393  69  26  24]:0.6916167664670658.
#              |->> Overriding with STOP
#       |->> #9-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [391  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.729 0.003 0.011 0.253 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
#          |->> Hit a STOP on the 9-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [392,  69,  26,  24] -> [391,  69,  26,  24] (Target was [392,  71,  22,  23])
#    |->> t=1 Diff-Reward (1.0) for LEFT:bbox transition: [392,  69,  26,  24] -> [391,  69,  26,  24] w/ P(a|s)=0.7500813007354736 and iou=0.7492260061919505 and reward=1.0
#    |->> t=2 Stop-Reward (1.0) for STOP:bbox transition: [391,  69,  26,  24] -> [391,  69,  26,  24] w/ P(a|s)=4.4735784854310623e-07 and iou=0.7492260061919505 and reward=1.0
#    |->> Assigned rewards: [0.28757367 9.2103405 ]
# >> Total frame loss: 9.49791431427002
# >> Attempting to reach frame 121 with src: [391,  69,  26,  24] and target: [388,  72,  22,  23]
# Frame path: adnet_datasets/OTB/Biker/img/0121.jpg
#      |->> Beginning tracking for bbox:[391  69  26  24]
#       |->> #9-th Action selection: 0/LEFT (P(a|s) = 0.7390000224113464)
#          |->> Bounding box moves to: [390  69  26  24]
#          |->> Action Probabilities (ROUNDED): [0.739 0.003 0.01  0.243 0.001 0.    0.    0.001 0.    0.002 0.001], argmax=0
# ...
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [371,  79,  20,  20] -> [370,  79,  20,  20] w/ P(a|s)=0.7650531530380249 and iou=0.44889779559118237 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [370,  79,  20,  20] -> [369,  79,  20,  20] w/ P(a|s)=0.708465576171875 and iou=0.40388349514563104 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [369,  79,  20,  20] -> [368,  79,  20,  20] w/ P(a|s)=0.6876429915428162 and iou=0.3615819209039548 and reward=-1.0
#    |->> t=4 Stop-Reward (-1.0) for STOP:bbox transition: [368,  79,  20,  20] -> [368,  79,  20,  20] w/ P(a|s)=6.163792676261437e-08 and iou=0.3615819209039548 and reward=-1.0
#    |->> Assigned rewards: [-0.26780996 -0.34465382 -0.3744855  -9.2103405 ]
# >> Total frame loss: -10.19728946685791
# >> Attempting to reach frame 138 with src: [368,  79,  20,  20] and target: [374,  83,  17,  19]
# Frame path: adnet_datasets/OTB/Biker/img/0138.jpg
#      |->> Beginning tracking for bbox:[368  79  20  20]
#       |->> #19-th Action selection: 0/LEFT (P(a|s) = 0.6850000023841858)
#          |->> Bounding box moves to: [367  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.685 0.003 0.012 0.295 0.    0.    0.    0.001 0.    0.003 0.   ], argmax=0
#       |->> #20-th Action selection: 0/LEFT (P(a|s) = 0.6299999952316284)
#          |->> Bounding box moves to: [366  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.63  0.005 0.018 0.339 0.    0.    0.    0.002 0.    0.005 0.001], argmax=0
#       |->> #21-th Action selection: 0/LEFT (P(a|s) = 0.6200000047683716)
#          |->> Bounding box moves to: [365  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.62  0.006 0.021 0.343 0.001 0.    0.    0.002 0.    0.006 0.001], argmax=0
#              |->> Revisiting bbox: [367  79  20  20]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #22-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [365  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.591 0.008 0.026 0.361 0.001 0.    0.    0.003 0.    0.008 0.001], argmax=0
#          |->> Hit a STOP on the 22-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [368,  79,  20,  20] -> [365,  79,  20,  20] (Target was [374,  83,  17,  19])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [368,  79,  20,  20] -> [367,  79,  20,  20] w/ P(a|s)=0.6849567294120789 and iou=0.40388349514563104 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [367,  79,  20,  20] -> [366,  79,  20,  20] w/ P(a|s)=0.6303449273109436 and iou=0.3615819209039548 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [366,  79,  20,  20] -> [365,  79,  20,  20] w/ P(a|s)=0.6197828054428101 and iou=0.3217550274223035 and reward=-1.0
#    |->> t=4 Stop-Reward (-1.0) for STOP:bbox transition: [365,  79,  20,  20] -> [365,  79,  20,  20] w/ P(a|s)=4.0710870052862447e-07 and iou=0.3217550274223035 and reward=-1.0
#    |->> Assigned rewards: [-0.3783996  -0.46148813 -0.47838616 -9.2103405 ]
# >> Total frame loss: -10.528614044189453
# >> Attempting to reach frame 139 with src: [365,  79,  20,  20] and target: [374,  84,  17,  19]
# Frame path: adnet_datasets/OTB/Biker/img/0139.jpg
#      |->> Beginning tracking for bbox:[365  79  20  20]
#       |->> #22-th Action selection: 0/LEFT (P(a|s) = 0.628000020980835)
#          |->> Bounding box moves to: [364  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.628 0.007 0.021 0.334 0.001 0.    0.    0.002 0.    0.007 0.001], argmax=0
#       |->> #23-th Action selection: 0/LEFT (P(a|s) = 0.5820000171661377)
#          |->> Bounding box moves to: [363  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.582 0.009 0.028 0.366 0.001 0.    0.    0.003 0.    0.009 0.001], argmax=0
#       |->> #24-th Action selection: 0/LEFT (P(a|s) = 0.578000009059906)
#          |->> Bounding box moves to: [362  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.578 0.011 0.031 0.363 0.001 0.    0.    0.004 0.    0.01  0.002], argmax=0
#       |->> #25-th Action selection: 0/LEFT (P(a|s) = 0.5590000152587891)
#          |->> Bounding box moves to: [361  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.559 0.012 0.036 0.371 0.002 0.    0.001 0.005 0.    0.012 0.002], argmax=0
#              |->> Revisiting bbox: [363  79  20  20]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #26-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [361  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.552 0.014 0.038 0.37  0.002 0.001 0.001 0.006 0.    0.014 0.003], argmax=0
#          |->> Hit a STOP on the 26-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [365,  79,  20,  20] -> [361,  79,  20,  20] (Target was [374,  84,  17,  19])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [365,  79,  20,  20] -> [364,  79,  20,  20] w/ P(a|s)=0.6275770664215088 and iou=0.2617801047120419 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [364,  79,  20,  20] -> [363,  79,  20,  20] w/ P(a|s)=0.5824572443962097 and iou=0.22959183673469388 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for LEFT:bbox transition: [363,  79,  20,  20] -> [362,  79,  20,  20] w/ P(a|s)=0.5777814984321594 and iou=0.19900497512437812 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [362,  79,  20,  20] -> [361,  79,  20,  20] w/ P(a|s)=0.5589422583580017 and iou=0.16990291262135923 and reward=-1.0
#    |->> t=5 Stop-Reward (-1.0) for STOP:bbox transition: [361,  79,  20,  20] -> [361,  79,  20,  20] w/ P(a|s)=2.633526264617103e-06 and iou=0.16990291262135923 and reward=-1.0
#    |->> Assigned rewards: [-0.4658888  -0.5404995  -0.54855955 -0.5817091  -9.2103405 ]
# >> Total frame loss: -11.346997261047363
# >> Attempting to reach frame 140 with src: [361,  79,  20,  20] and target: [374,  84,  17,  19]
# Frame path: adnet_datasets/OTB/Biker/img/0140.jpg
#      |->> Beginning tracking for bbox:[361  79  20  20]
#       |->> #26-th Action selection: 0/LEFT (P(a|s) = 0.5839999914169312)
#          |->> Bounding box moves to: [360  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.584 0.012 0.033 0.348 0.002 0.    0.001 0.005 0.    0.012 0.002], argmax=0
#       |->> #27-th Action selection: 1/2X LEFT (P(a|s) = 0.014000000432133675)
#          |->> Bounding box moves to: [358  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.547 0.014 0.04  0.372 0.002 0.001 0.001 0.007 0.    0.014 0.003], argmax=0
#              |->> Revisiting bbox: [360  79  20  20]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #28-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [358  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.577 0.014 0.035 0.346 0.002 0.001 0.001 0.007 0.    0.014 0.003], argmax=0
#          |->> Hit a STOP on the 28-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [361,  79,  20,  20] -> [358,  79,  20,  20] (Target was [374,  84,  17,  19])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [361,  79,  20,  20] -> [360,  79,  20,  20] w/ P(a|s)=0.5841450691223145 and iou=0.14218009478672985 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for 2X LEFT:bbox transition: [360,  79,  20,  20] -> [358,  79,  20,  20] w/ P(a|s)=0.014063005335628986 and iou=0.09049773755656108 and reward=-1.0
#    |->> t=3 Stop-Reward (-1.0) for STOP:bbox transition: [358,  79,  20,  20] -> [358,  79,  20,  20] w/ P(a|s)=3.4283589229744393e-06 and iou=0.09049773755656108 and reward=-1.0
#    |->> Assigned rewards: [-0.53760594 -4.264208   -9.2103405 ]
# >> Total frame loss: -14.012153625488281
# >> Attempting to reach frame 141 with src: [358,  79,  20,  20] and target: [374,  84,  17,  19]
# Frame path: adnet_datasets/OTB/Biker/img/0141.jpg
#      |->> Beginning tracking for bbox:[358  79  20  20]
#       |->> #28-th Action selection: 0/LEFT (P(a|s) = 0.5659999847412109)
#          |->> Bounding box moves to: [357  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.566 0.014 0.039 0.353 0.002 0.001 0.001 0.007 0.    0.015 0.003], argmax=0
#       |->> #29-th Action selection: 0/LEFT (P(a|s) = 0.5509999990463257)
#          |->> Bounding box moves to: [356  79  20  20]
#          |->> Action Probabilities (ROUNDED): [0.551 0.015 0.04  0.365 0.002 0.001 0.001 0.007 0.    0.015 0.003], argmax=0
#       |->> #30-th Action selection: 9/SCALE DOWN (P(a|s) = 0.014999999664723873)
#          |->> Bounding box moves to: [357  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.548 0.015 0.041 0.367 0.002 0.001 0.001 0.007 0.    0.015 0.003], argmax=0
#       |->> #31-th Action selection: 0/LEFT (P(a|s) = 0.5600000023841858)
#          |->> Bounding box moves to: [356  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.56  0.015 0.039 0.356 0.003 0.001 0.001 0.007 0.    0.015 0.004], argmax=0
#       |->> #32-th Action selection: 0/LEFT (P(a|s) = 0.5360000133514404)
#          |->> Bounding box moves to: [355  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.536 0.017 0.045 0.37  0.003 0.001 0.001 0.008 0.    0.016 0.004], argmax=0
#       |->> #33-th Action selection: 0/LEFT (P(a|s) = 0.5389999747276306)
#          |->> Bounding box moves to: [354  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.539 0.017 0.043 0.368 0.003 0.001 0.001 0.008 0.    0.016 0.004], argmax=0
#       |->> #34-th Action selection: 0/LEFT (P(a|s) = 0.5320000052452087)
#          |->> Bounding box moves to: [353  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.532 0.017 0.045 0.371 0.003 0.001 0.001 0.008 0.    0.017 0.004], argmax=0
#       |->> #35-th Action selection: 0/LEFT (P(a|s) = 0.5289999842643738)
#          |->> Bounding box moves to: [352  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.529 0.018 0.046 0.373 0.003 0.001 0.001 0.009 0.    0.017 0.004], argmax=0
#       |->> #36-th Action selection: 0/LEFT (P(a|s) = 0.5239999890327454)
#          |->> Bounding box moves to: [351  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.524 0.018 0.047 0.375 0.003 0.001 0.001 0.009 0.    0.018 0.004], argmax=0
#       |->> #37-th Action selection: 0/LEFT (P(a|s) = 0.5270000100135803)
#          |->> Bounding box moves to: [350  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.527 0.018 0.047 0.371 0.003 0.001 0.001 0.009 0.    0.018 0.004], argmax=0
#       |->> #38-th Action selection: 0/LEFT (P(a|s) = 0.5249999761581421)
#          |->> Bounding box moves to: [349  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.525 0.019 0.048 0.371 0.003 0.001 0.001 0.009 0.    0.018 0.004], argmax=0
#       |->> #39-th Action selection: 0/LEFT (P(a|s) = 0.5189999938011169)
#          |->> Bounding box moves to: [348  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.519 0.019 0.049 0.373 0.003 0.001 0.001 0.01  0.    0.019 0.005], argmax=0
#       |->> #40-th Action selection: 0/LEFT (P(a|s) = 0.5180000066757202)
#          |->> Bounding box moves to: [347  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.518 0.02  0.05  0.373 0.004 0.001 0.002 0.01  0.    0.019 0.005], argmax=0
#       |->> #41-th Action selection: 0/LEFT (P(a|s) = 0.5189999938011169)
#          |->> Bounding box moves to: [346  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.519 0.019 0.05  0.371 0.004 0.001 0.002 0.01  0.    0.019 0.005], argmax=0
#              |->> Revisiting bbox: [348  80  18  18]. Breaking action sequence
#              |->> Overriding with STOP
#       |->> #42-th Action selection: 8/STOP (P(a|s) = 0.0)
#          |->> Bounding box moves to: [346  80  18  18]
#          |->> Action Probabilities (ROUNDED): [0.518 0.02  0.05  0.37  0.004 0.001 0.002 0.01  0.    0.019 0.005], argmax=0
#          |->> Hit a STOP on the 42-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [358,  79,  20,  20] -> [346,  80,  18,  18] (Target was [374,  84,  17,  19])
#    |->> t=1 Diff-Reward (-1.0) for LEFT:bbox transition: [358,  79,  20,  20] -> [357,  79,  20,  20] w/ P(a|s)=0.5659638047218323 and iou=0.06637168141592921 and reward=-1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [357,  79,  20,  20] -> [356,  79,  20,  20] w/ P(a|s)=0.5505236387252808 and iou=0.04329004329004329 and reward=-1.0
#    |->> t=3 Diff-Reward (-1.0) for SCALE DOWN:bbox transition: [356,  79,  20,  20] -> [357,  80,  18,  18] w/ P(a|s)=0.01510603167116642 and iou=0.022116903633491312 and reward=-1.0
#    |->> t=4 Diff-Reward (-1.0) for LEFT:bbox transition: [357,  80,  18,  18] -> [356,  80,  18,  18] w/ P(a|s)=0.5596851110458374 and iou=0.0 and reward=-1.0
#    |->> t=5 Diff-Reward (-1.0) for LEFT:bbox transition: [356,  80,  18,  18] -> [355,  80,  18,  18] w/ P(a|s)=0.5359780788421631 and iou=0.0 and reward=-1.0
#    |->> t=6 Diff-Reward (-1.0) for LEFT:bbox transition: [355,  80,  18,  18] -> [354,  80,  18,  18] w/ P(a|s)=0.5392533540725708 and iou=0.0 and reward=-1.0
#    |->> t=7 Diff-Reward (-1.0) for LEFT:bbox transition: [354,  80,  18,  18] -> [353,  80,  18,  18] w/ P(a|s)=0.5322353839874268 and iou=0.0 and reward=-1.0
#    |->> t=8 Diff-Reward (-1.0) for LEFT:bbox transition: [353,  80,  18,  18] -> [352,  80,  18,  18] w/ P(a|s)=0.5289174914360046 and iou=0.0 and reward=-1.0
#    |->> t=9 Diff-Reward (-1.0) for LEFT:bbox transition: [352,  80,  18,  18] -> [351,  80,  18,  18] w/ P(a|s)=0.5235093235969543 and iou=0.0 and reward=-1.0
#    |->> t=10 Diff-Reward (-1.0) for LEFT:bbox transition: [351,  80,  18,  18] -> [350,  80,  18,  18] w/ P(a|s)=0.527389645576477 and iou=0.0 and reward=-1.0
#    |->> t=11 Diff-Reward (-1.0) for LEFT:bbox transition: [350,  80,  18,  18] -> [349,  80,  18,  18] w/ P(a|s)=0.5248901844024658 and iou=0.0 and reward=-1.0
#    |->> t=12 Diff-Reward (-1.0) for LEFT:bbox transition: [349,  80,  18,  18] -> [348,  80,  18,  18] w/ P(a|s)=0.5194899439811707 and iou=0.0 and reward=-1.0
#    |->> t=13 Diff-Reward (-1.0) for LEFT:bbox transition: [348,  80,  18,  18] -> [347,  80,  18,  18] w/ P(a|s)=0.5175778865814209 and iou=0.0 and reward=-1.0
#    |->> t=14 Diff-Reward (-1.0) for LEFT:bbox transition: [347,  80,  18,  18] -> [346,  80,  18,  18] w/ P(a|s)=0.5194695591926575 and iou=0.0 and reward=-1.0
#    |->> t=15 Stop-Reward (-1.0) for STOP:bbox transition: [346,  80,  18,  18] -> [346,  80,  18,  18] w/ P(a|s)=1.0902950634772424e-05 and iou=0.0 and reward=-1.0
#    |->> Assigned rewards: [-0.56922513 -0.5968854  -4.1926613  -0.580381   -0.623662   -0.6175698
#  -0.6306694  -0.63692284 -0.64720047 -0.6398156  -0.64456624 -0.6549078
#  -0.65859526 -0.65494704 -9.2103405 ]
# >> Total frame loss: -21.558349609375
# Final bounding box: [346  80  18  18] reached in 42 timesteps (originating from [383  79  20  20]). Target was [374  84  17  19]
# Total Episode Loss: -3.7713494300842285  with starting action STOP (P(a|s)=3.312583931117108e-12). Previous episode starting action: N/A (P(a|s)=-1.0)
#
# ############# END EPISODE # 142 in t=42 timesteps ################
# EPISODE LOSSES: [-3.7713494]
# Layer Name: conv_1/kernel:0, GRAD NORM = 2.0860214233398438
# Layer Name: conv_1/bias:0, GRAD NORM = 0.0010859929025173187
# Layer Name: conv_2/kernel:0, GRAD NORM = 3.0204291343688965
# Layer Name: conv_2/bias:0, GRAD NORM = 0.0006484067416749895
# Layer Name: conv_3/kernel:0, GRAD NORM = 4.816684722900391
# Layer Name: conv_3/bias:0, GRAD NORM = 0.0009636958129703999
# Layer Name: fc1/kernel:0, GRAD NORM = 9.068269729614258
# Layer Name: fc1/bias:0, GRAD NORM = 0.001954723382368684
# Layer Name: fc2/kernel:0, GRAD NORM = 113.6988525390625
# Layer Name: fc2/bias:0, GRAD NORM = 0.06049781292676926
# Layer Name: fc3/kernel:0, GRAD NORM = 319.3789367675781
# Layer Name: fc3/bias:0, GRAD NORM = 1.4670279026031494
# #################################################
# #################################################
# Training complete
# Text(0, 0.5, 'Sequence Loss')

# %%
bad_data_logs

# %%
# !nvidia-smi
# Out:
# Sun Dec 12 00:08:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    33W / 250W |  15981MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
fig = plt.figure()
plt.plot([np.arange(10)) for _ in range(10)], losses) # Plot losses with # episodes
plt.xlabel('Number of Episodes')
plt.ylabel('Sequence Loss')

# %% [markdown]
# # Prediction

# %%
print(erroneous_datasets)

# !ls adnet_datasets/OTB/Diving/img/
# ! wc -l adnet_datasets/OTB/Diving/groundtruth_rect.txt
# Out:
# ['adnet_datasets/OTB/Diving']

# %%
def predict(model: tf.keras.Model,img: np.array,bbox: np.array) -> np.array:
  ACTION_DIM=11
  K=10
  
  action_hist = np.zeros((ACTION_DIM * K, 1))
  seen_bboxes = set()
  for t in range(K):
    #model.setActionHistory(action_hist.reshape((1, 1, 1, ACTION_DIM * K)))
    model.setActionHistory(action_hist.reshape((1,ACTION_DIM * K))) ### For ADNET_v2
    patch = tf.image.resize(img[bbox[1]:(bbox[1] + bbox[3]), 
                                bbox[0]:(bbox[0] + bbox[2])], [112, 112])
    patch = tf.reshape(patch, (1, 112, 112, 3))
    a_prob = tf.reshape(model(patch)[0], (ACTION_DIM)) 
    a, bbox = selectAction(np.array(img), bbox, a_prob)
    if isStop(a) or tuple(bbox) in seen_bboxes:
      break

    action_hist[t * ACTION_DIM + a] = 1 
    seen_bboxes.add(tuple(bbox))
  return bbox

# %%
def plotNpImageBBoxGT(img: np.array, bbox: np.array,gbbox: np.array) -> np.array:
  '''
  Plots the bounding box on an image and returns the bounding box
  '''
  fig, ax = plt.subplots()
  x_pre,y_pre, w_pre, h_pre = bbox
  x_gr,y_gr, w_gr, h_gr = gbbox
  predicted_rect = patches.Rectangle((x_pre, y_pre), w_pre, h_pre, linewidth=1, edgecolor='r', facecolor='none')
  gt_rect = patches.Rectangle((x_gr, y_gr), w_gr, h_gr, linewidth=1, edgecolor='b', facecolor='none')
  ax.add_patch(predicted_rect)
  ax.add_patch(gt_rect)
  plt.imshow(img)
  return bbox

# %%
ALL_DATASETS_LIST = glob.glob("adnet_datasets/OTB/*")
j = random.randint(0, len(ALL_DATASETS_LIST)) 
dataset = ALL_DATASETS_LIST[j] 
frames = sorted(glob.glob(os.path.join('%s/img' % dataset, '*.jpg')))
gt = get_ground_truths("%s/groundtruth_rect.txt" % dataset)

predicted_bbox = gt[0]
for i, frame in enumerate(frames[1:]):
  img = cv2.imread(frame)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  print(img.shape)
  predicted_bbox=predict(model,img,predicted_bbox)
  print(predicted_bbox)
  gtbbox=gt[i]
  plotNpImageBBoxGT(img,predicted_bbox,gtbbox)
  #print(gtbbox)
  #print(predicted_bbox)
  break
  #bbox = 
  #print(model)
# Out:
# (240, 320, 3)
# [139 112  51  36]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-59-8fd76aa49e33> in <module>()
#      11   print(img.shape)
#      12   print(gt[0])
# ---> 13   predicted_bbox=predict(model,img,predicted_bbox)
#      14   print(predicted_bbox)
#      15   gtbbox=gt[i]
#
# <ipython-input-54-cffae5f55ea3> in predict(model, img, bbox)
#       9     model.setActionHistory(action_hist.reshape((1,ACTION_DIM * K))) ### For ADNET_v2
#      10     patch = tf.image.resize(img[bbox[1]:(bbox[1] + bbox[3]),
# ---> 11                                 bbox[0]:(bbox[0] + bbox[2])], [112, 112])
#      12     patch = tf.reshape(patch, (1, 112, 112, 3))
#      13     a_prob = tf.reshape(model(patch)[0], (ACTION_DIM))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7105 def raise_from_not_ok_status(e, name):
#    7106   e.message += (" name: " + name if name is not None else "")
# -> 7107   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7108
#    7109
#
# InvalidArgumentError: input image must be of non-zero size [Op:ResizeBilinear]

# %% [markdown]
# # TEST

# %%
# VERTICAL MOVEMENT TESTING 
TEST_IMAGE_PATH = "adnet_datasets/OTB/Skater2/img/0005.jpg"
TEST_BBOX = get_ground_truths("adnet_datasets/OTB/Skater2/groundtruth_rect.txt")[4]
TEST_IMAGE = cv2.imread(TEST_IMAGE_PATH)

# Test move down
print("Down-shifted bounding box")
bbox = move2(img, TEST_BBOX, "down")
print(plotNpImageBBox(img, bbox))

print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))

print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))

print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))


print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))

# %%
# HORIZONTAL MOVEMENT TESTING 
TEST_IMAGE_PATH = "adnet_datasets/OTB/Skater2/img/0005.jpg"
TEST_BBOX = get_ground_truths("adnet_datasets/OTB/Skater2/groundtruth_rect.txt")[4]
TEST_IMAGE = cv2.imread(TEST_IMAGE_PATH)

img, bbox = TEST_IMAGE, TEST_BBOX
print("Original bounding box")
print(plotNpImageBBox(img, TEST_BBOX))

# Test move left
print("Left-shifted bounding box")
bbox = move2(img, TEST_BBOX, "left")
print(plotNpImageBBox(img, bbox))

# %%
# MOVEMENT TEST

print("IOU between {1} and {2} is {0}".format(calculate_IOU(np.array([143, 131,  34,  87]), np.array([138,  41,  32,  89])), [143, 131,  34,  87], [138,  41,  32,  89]))

for i in range(11):
  print(selectAction(np.zeros([300, 300, 3]), np.array([252, 65, 25, 30]), i))

print(selectAction(np.zeros([300, 300, 3]), np.array([131,7,117,168]), 5))
print("The following UP should do nothing because 0.03 * 168 * 2 is too large")
print(selectAction(np.zeros([300, 300, 3]), np.array([131,7,117,168]), 5))
# Out:
# IOU between [143, 131, 34, 87] and [138, 41, 32, 89] is 0.0
# (0, array([251,  65,  25,  30]))
# (1, array([250,  65,  25,  30]))
# (2, array([253,  65,  25,  30]))
# (3, array([254,  65,  25,  30]))
# (4, array([252,  64,  25,  30]))
# (5, array([252,  63,  25,  30]))
# (6, array([252,  66,  25,  30]))
# (7, array([252,  67,  25,  30]))
# (8, array([252,  65,  25,  30]))
# (9, array([253,  66,  23,  28]))
# (10, array([251,  64,  27,  32]))
# (5, array([131,   7, 117, 168]))
# The following UP should do nothing because 0.03 * 168 * 2 is too large
# (5, array([131,   7, 117, 168]))

# %%
print(selectAction(np.zeros([450, 450, 3]), np.array([315,  0, 32,  35]), 5))
# Out:
# (5, array([315,   0,  32,  35]))
